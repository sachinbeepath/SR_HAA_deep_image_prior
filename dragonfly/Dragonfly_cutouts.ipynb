# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy import wcs
from astropy.nddata.utils import Cutout2D
import os

# %% [markdown]
# Gets cutouts of s

# %%
i = 1
for file in os.listdir(os.getcwd()):
    if file.endswith('.fits'):
        print(file)
        data, hdr = fits.getdata(file, 0, header=True) #'sci' image[1] data and header
        filt= hdr['FILTER']
        w = wcs.WCS(hdr)
        pixcrd2 = w.wcs_world2pix([[189.09, 25.99]], 0)
        centered_cut = Cutout2D(data, (pixcrd2[0][0], pixcrd2[0][1]), (256, 256))
        if  centered_cut.data.shape == (256,256):
            result = 1
            if filt == 'SloanR':
                print(filt)
                #fits.writeto('cutout_SloanR_' + file, centered_cut.data, header=hdr, overwrite =True)
            elif filt == 'SloanG':
                print(filt)
                #fits.writeto('cutout_SloanG_' + file, centered_cut.data, header=hdr, overwrite =True)
            plt.imshow(centered_cut.data)
            plt.show()
            i +=1
    else: 
        continue
# Out:
# 2017-03-25-T13110630_11_light_ds_ff.fits
# SloanR
# WARNING: FITSFixedWarning: EPOCH = 'JNOW '
# a floating-point value was expected. [astropy.wcs.wcs]
# 2017-03-26-83F010827_11_light_ds_ff.fits
# SloanG
# 2017-03-26-T13060460_11_light_ds_ff.fits
# SloanR
# 2017-03-26-T13080513_11_light_ds_ff.fits
# SloanR
# 2017-03-26-T13090526_11_light_ds_ff.fits
# SloanR
# 2017-03-26-T13090528_11_light_ds_ff.fits
# SloanR
# 2017-03-26-T13090552_11_light_ds_ff.fits
# SloanR
# 2017-03-26-T13090553_11_light_ds_ff.fits
# SloanR
# 2017-03-26-T13090554_11_light_ds_ff.fits
# 2017-03-26-T13090562_11_light_ds_ff.fits
# SloanR
# 2017-03-26-T13090564_11_light_ds_ff.fits
# 2017-03-26-T13090565_11_light_ds_ff.fits
# 2017-03-26-T13090568_11_light_ds_ff.fits
# 2017-03-26-T13090571_11_light_ds_ff.fits
# 2017-03-26-T13100579_11_light_ds_ff.fits
# 2017-03-26-T13100588_11_light_ds_ff.fits
# SloanR
# 2017-03-26-T13100590_11_light_ds_ff.fits
# 2017-03-26-T13100591_11_light_ds_ff.fits
# SloanR
# ...
